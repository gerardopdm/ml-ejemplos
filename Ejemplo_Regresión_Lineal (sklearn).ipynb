# %% [markdown]
# <a href="https://colab.research.google.com/github/gerardopdm/ml-ejemplos/blob/master/Ejemplo_Regresi%C3%B3n_Lineal%20(sklearn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
df1=pd.read_excel("https://www.dropbox.com/s/oxjqe4lw1mhiefh/estudio_pies.xlsx?dl=1")

# %%
df1.head(5)
# Out:
#    No.            ID  'Free' GENERO  ...  PESO  TALLA  RECIO ANCHO METATARSAL
# 0  129  G9BN11EQ4NUY     NaN      M  ...    54   23.0  223.6             93.3
# 1  129  G9BN11EQ4NUY     NaN      M  ...    54   23.0  222.6             92.0
# 2    2  G9BN1120EJ0S     NaN      F  ...    55   23.0  243.1             98.9
# 3    2  G9BN1120EJ0S     NaN      F  ...    55   23.0  234.7             98.3
# 4  108  G9BN11EQ41OL     NaN      M  ...    55   23.0  235.4             98.4
#
# [5 rows x 14 columns]

# %%
df1.dtypes
# Out:
# No.                    int64
# ID                    object
# 'Free'               float64
# GENERO                object
# AÑO DE NACIMIENTO      int64
# EDAD                   int64
# LADO                  object
# HORA DE ESCANEO       object
# TURNO                 object
# ALTURA                 int64
# PESO                   int64
# TALLA                float64
# RECIO                float64
# ANCHO METATARSAL     float64
# dtype: object

# %%
df1.describe()
# Out:
#               No.  'Free'  ...       RECIO  ANCHO METATARSAL
# count  348.000000     0.0  ...  348.000000        348.000000
# mean    87.500000     NaN  ...  249.165230        103.372989
# std     50.300967     NaN  ...   12.605176          5.359138
# min      1.000000     NaN  ...  214.700000         88.600000
# 25%     44.000000     NaN  ...  241.275000         99.800000
# 50%     87.500000     NaN  ...  249.200000        103.000000
# 75%    131.000000     NaN  ...  256.800000        107.000000
# max    174.000000     NaN  ...  296.300000        122.200000
#
# [8 rows x 9 columns]

# %%
df1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f113b48f668>,
# ...
#       dtype=object)

# %%
df1[df1["GENERO"]=="M"]["PESO"].hist()

# %%
df1[df1["GENERO"]=="F"]["PESO"].hist()

# %%
sns.set(rc={'figure.figsize':(8,5)})

# %%
sns.scatterplot(x="PESO", y="RECIO", data=df1, hue="GENERO")

# %%
sns.scatterplot(x="ANCHO METATARSAL", y="RECIO", data=df1, hue="GENERO")

# %%
X_train = df1["ANCHO METATARSAL"].values
y_train = df1["RECIO"].values

# %%
print("X:",X_train.shape)
print(X_train[0:5])
print()
print("y:",y_train.shape)
print(y_train[0:5])
# Out:
# X: (348,)
# [93.3 92.  98.9 98.3 98.4]
#
# y: (348,)
# [223.6 222.6 243.1 234.7 235.4]

# %%
X_train = X_train.reshape((348, 1))
y_train = y_train.reshape((-1, 1))

# %%
print("X:",X_train.shape)
print(X_train[0:5])
print()
print("y:",y_train.shape)
print(y_train[0:5])
# Out:
# X: (348, 1)
# [[93.3]
#  [92. ]
#  [98.9]
#  [98.3]
#  [98.4]]
#
# y: (348, 1)
# [[223.6]
#  [222.6]
#  [243.1]
#  [234.7]
#  [235.4]]

# %%
# Creamos el objeto de Regresión Linear
regr = linear_model.LinearRegression()

# %%
# Entrenamos nuestro modelo
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Hacemos las predicciones que en definitiva una línea (en este caso, al ser 2D)
y_pred = regr.predict(X_train)

# %%
print(X_train[0:5])
print(y_pred[0:5])
# Out:
# [[93.3]
#  [92. ]
#  [98.9]
#  [98.3]
#  [98.4]]
# [[226.63278642]
#  [223.72479378]
#  [239.15952398]
#  [237.81737352]
#  [238.04106527]]

# %%
plt.scatter(x=X_train, y=y_train, marker=".")
plt.scatter(x=X_train, y=y_pred, marker="*")

# %%
regr.
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}
