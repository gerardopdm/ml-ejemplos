# %% [markdown]
# <a href="https://colab.research.google.com/github/gerardopdm/ml-ejemplos/blob/master/antropometrico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_excel("Prueba Estudio_antropodometrico_Carlitos_2010.xlsx")
df1.drop(index=0,inplace=True)

# %%
df1.drop(351, inplace=True)

# %%
df1.head(3)
# Out:
#    No.            ID  ... LARGO ARCO     Unnamed: 37
# 1  1.0  G9BN1120EJ0R  ...      103.6             NaN
# 2  1.0  G9BN1120EJ0R  ...      106.5             NaN
# 3  2.0  G9BN1120EJ0S  ...      129.5  O.K. Descartar
#
# [3 rows x 38 columns]

# %%
df1.corr()
# Out:
#                                     No.  'Free'  ...  ANCHO ARCO  LARGO ARCO
# No.                            1.000000     NaN  ...   -0.146468    0.019060
# 'Free'                              NaN     NaN  ...         NaN         NaN
# AÑO DE NACIMIENTO              0.114964     NaN  ...   -0.177608    0.133855
# EDAD (años)                   -0.114964     NaN  ...    0.177608   -0.133855
# ALTURA (cm)                   -0.034292     NaN  ...    0.095591    0.533982
# PESO (kg)                      0.186734     NaN  ...   -0.208321    0.383357
# IMC                            0.255624     NaN  ...   -0.318681    0.138708
# RECIO (mm)                     0.122054     NaN  ...   -0.099237    0.233612
# ANCHO METATARSAL (mm)          0.116564     NaN  ...   -0.167992    0.201824
# PERIMETRO DEL EMPIENE (mm)     0.134132     NaN  ...   -0.191335    0.293370
# ANCHO DEL TALON (mm)           0.169182     NaN  ...   -0.192632    0.309224
# ...

# %%
df1["TALLA"].hist(bins=[22,22.5,23,23.5,24,24.5,25,25.5,26])

# %%
df1["TALLA"]=df1["TALLA"].astype("float64")

# %%
df1["GENERO"].head()
# Out:
# 1    M
# 2    M
# 3    F
# 4    F
# 5    M
# Name: GENERO, dtype: object

# %%
df1.dtypes
# Out:
# No.                                     float64
# ID                                       object
# NOMBRE                                   object
# 'Free'                                  float64
# GENERO                                   object
# AÑO DE NACIMIENTO                       float64
# EDAD (años)                             float64
# LADO                                     object
# FECHA DE ESCANEO                 datetime64[ns]
# HORA DE ESCANEO                          object
# TURNO                                    object
# ALTURA (cm)                             float64
# PESO (kg)                               float64
# IMC                                     float64
# POSTURA                                  object
# LONGITUD DEL PIE (mm)                    object
# TALLA                                   float64
# RECIO (mm)                              float64
# ANCHO METATARSAL (mm)                   float64
# PERIMETRO DEL EMPIENE (mm)              float64
# ...

# %%
df2=df1.select_dtypes(include='float64')

# %%
sns.set(rc={'figure.figsize':(8,5)})

# %%
sns.scatterplot(x="ANCHO METATARSAL (mm)", y="RECIO (mm)", data=df1, hue="GENERO")

# %%
sns.regplot(df1["ANCHO METATARSAL (mm)"],df1["RECIO (mm)"], marker=".")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df1["RECIO (mm)"].hist(bins=12)

# %%
df2.corr()
# Out:
#                                     No.  'Free'  AÑO DE NACIMIENTO  \
# No.                            1.000000     NaN           0.114964
# 'Free'                              NaN     NaN                NaN
# AÑO DE NACIMIENTO              0.114964     NaN           1.000000
# EDAD (años)                   -0.114964     NaN          -1.000000
# ALTURA (cm)                   -0.034292     NaN           0.088445
# PESO (kg)                      0.186734     NaN           0.350688
# IMC                            0.255624     NaN           0.364398
# TALLA                         -0.057701     NaN           0.133981
# RECIO (mm)                     0.122054     NaN           0.121433
# ANCHO METATARSAL (mm)          0.116564     NaN           0.108517
# PERIMETRO DEL EMPIENE (mm)     0.134132     NaN           0.180989
# ANCHO DEL TALON (mm)           0.169182     NaN           0.166180
# LONG TALON 1er METATARSO (mm) -0.010845     NaN           0.156587
# ...

# %%
sns.heatmap(df2.corr(), cmap='Reds')

# %%
df2[df2.columns[3:16]].head()
# Out:
#    EDAD (años)  ALTURA (cm)  PESO (kg)        IMC  TALLA  RECIO (mm)  \
# 1         42.0        165.0       71.0  26.078972   25.5       256.0
# 2         42.0        165.0       71.0  26.078972   25.0       248.0
# 3         62.0        142.0       55.0  27.276334   23.0       243.1
# 4         62.0        142.0       55.0  27.276334   23.0       234.7
# 5         48.0        161.0       78.0  30.091432   25.5       244.9
#
#    ANCHO METATARSAL (mm)  PERIMETRO DEL EMPIENE (mm)  ANCHO DEL TALON (mm)  \
# 1                  106.5                       254.1                  66.7
# 2                  103.0                       251.0                  67.8
# 3                   98.9                       232.2                  66.3
# 4                   98.3                       233.4                  65.1
# 5                  100.6                       260.4                  73.0
#
#    LONG TALON 1er METATARSO (mm)  LONG TALON 5to METATARSO (mm)  \
# ...

# %%
df3=df2.select_dtypes(include='float64')

# %%
df3.dtypes
# Out:
# No.                              float64
# 'Free'                           float64
# AÑO DE NACIMIENTO                float64
# EDAD (años)                      float64
# ALTURA (cm)                      float64
# PESO (kg)                        float64
# IMC                              float64
# TALLA                            float64
# RECIO (mm)                       float64
# ANCHO METATARSAL (mm)            float64
# PERIMETRO DEL EMPIENE (mm)       float64
# ANCHO DEL TALON (mm)             float64
# LONG TALON 1er METATARSO (mm)    float64
# LONG TALON 5to METATARSO (mm)    float64
# ALTURA DEL RECIO (mm)            float64
# ALTURA DEL EMPEINE (mm)          float64
# ANGULO DEL 1er DEDO              float64
# ANGULO DEL 5to DEDO              float64
# ALTURA DEL 1er DEDO (mm)         float64
# ALTURA DEL 5to DEDO (mm)         float64
# ALTURA NAVICULAR (mm)            float64
# LONGITUD DE ARCO (mm)            float64
# ANGULO DEL CALCANEO              float64
# ...

# %%
df3.drop(columns=["No.","'Free'","AÑO DE NACIMIENTO"],inplace=True)

# %%
df3.dtypes
# Out:
# EDAD (años)                      float64
# ALTURA (cm)                      float64
# PESO (kg)                        float64
# IMC                              float64
# TALLA                            float64
# RECIO (mm)                       float64
# ANCHO METATARSAL (mm)            float64
# PERIMETRO DEL EMPIENE (mm)       float64
# ANCHO DEL TALON (mm)             float64
# LONG TALON 1er METATARSO (mm)    float64
# LONG TALON 5to METATARSO (mm)    float64
# ALTURA DEL RECIO (mm)            float64
# ALTURA DEL EMPEINE (mm)          float64
# ANGULO DEL 1er DEDO              float64
# ANGULO DEL 5to DEDO              float64
# ALTURA DEL 1er DEDO (mm)         float64
# ALTURA DEL 5to DEDO (mm)         float64
# ALTURA NAVICULAR (mm)            float64
# LONGITUD DE ARCO (mm)            float64
# ANGULO DEL CALCANEO              float64
# LARGO TALON                      float64
# ANCHO TALON                      float64
# ALTURA ARCO                      float64
# ...

# %%
df3["GENERO"]=df1["GENERO"]

# %%
df3[df3.columns[-5:]].head()
# Out:
#    ANCHO TALON  ALTURA ARCO  ANCHO ARCO  LARGO ARCO GENERO
# 1         49.3          6.0        25.1       103.6      M
# 2         48.2          6.1        25.3       106.5      M
# 3         26.7         11.9        37.3       129.5      F
# 4         47.1          9.3        35.2       122.0      F
# 5         52.1         18.9        43.7       141.7      M

# %%
df3.columns[0:10].append(df3.columns[-1:])
# Out:
# Index(['EDAD (años)', 'ALTURA (cm)', 'PESO (kg)', 'IMC', 'TALLA', 'RECIO (mm)',
#        'ANCHO METATARSAL (mm)', 'PERIMETRO DEL EMPIENE (mm)',
#        'ANCHO DEL TALON (mm)', 'LONG TALON 1er METATARSO (mm)', 'GENERO'],
#       dtype='object')

# %%
##### sns.set(style="ticks")
sns.pairplot(df3[df3.columns[0:10].append(df3.columns[-1:])],hue="GENERO")

# %%
sns.scatterplot(x="ANCHO METATARSAL (mm)", y="RECIO (mm)", data=df1, hue="GENERO", alpha=0.3, size="TALLA")

# %%
df3.shape
# Out:
# (367, 26)

# %%
sns.__version__
# Out:
# '0.9.0'
